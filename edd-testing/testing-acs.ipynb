# %%
import pandas as pd

# from lowe.locations.lookup import name2fips, fips2name, search
# from lowe.acs.ACSClient import ACSClient

# %%
empl_data = pd.read_csv("../data/CV_EMPL.csv", na_values=["***", ".", "NA"])

# %%
empl_data['DATE'] = empl_data['DATE'].str.pad(width=6, side="left", fillchar="0")

# %%
print(empl_data.head())
# Out:
#      DATE            City  Agriculture, Forestry, Fishing and Hunting  \
# 0  05-Jan  Cathedral City                                         NaN
# 1  05-Feb  Cathedral City                                         NaN
# 2  05-Mar  Cathedral City                                         NaN
# 3  05-Apr  Cathedral City                                         NaN
# 4  05-May  Cathedral City                                         NaN
#
#    Utilities  Construction  Manufacturing  Wholesale Trade  Retail Trade  \
# 0        NaN         971.0           79.0            106.0        1941.0
# 1        NaN         981.0           68.0            108.0        1956.0
# 2        NaN        1032.0           78.0            111.0        1947.0
# 3        NaN         988.0           86.0            154.0        1936.0
# 4        NaN        1028.0           88.0            154.0        1953.0
#
#    Transportation and Warehousing  Information  ...  Educational Services  \
# 0                            39.0        137.0  ...                  21.0
# 1                            39.0        143.0  ...                  14.0
# 2                            41.0        142.0  ...                  21.0
# 3                            41.0        140.0  ...                  20.0
# 4                            39.0        135.0  ...                  17.0
#
#    Health Care and Social Assistance  Arts, Entertainment, and Recreation  \
# 0                              530.0                                217.0
# 1                              517.0                                224.0
# 2                              513.0                                236.0
# 3                              523.0                                234.0
# 4                              529.0                                245.0
#
#    Accommodation and Food Services  \
# 0                            967.0
# 1                            990.0
# 2                           1000.0
# 3                           1023.0
# 4                           1022.0
#
#    Other Services (except Public Administration)  Federal Government  \
# 0                                          543.0                 NaN
# 1                                          547.0                 NaN
# 2                                          561.0                 NaN
# 3                                          546.0                 NaN
# 4                                          552.0                 NaN
#
#    Local Government  State Government  Not Elsewhere Classified  \
# 0             940.0               NaN                       NaN
# 1             941.0               NaN                       NaN
# 2             953.0               NaN                       NaN
# 3             906.0               NaN                       NaN
# 4             910.0               NaN                       NaN
#
#    Mining, Quarrying, and Oil and Gas Extraction
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
# [5 rows x 25 columns]

# %%
empl_data['DATE'] = pd.to_datetime(empl_data.DATE, format='%y-%b')

# %%
empl_data.set_index('DATE', inplace=True)

# %%
empl_data = empl_data.fillna(0)

# %%
empl_data['Total Employment'] = empl_data.loc[:, 'Agriculture, Forestry, Fishing and Hunting':].sum(axis=1)

# %%
print(empl_data.head())
# Out:
#                       City  Agriculture, Forestry, Fishing and Hunting  \
# DATE
# 2005-01-01  Cathedral City                                         0.0
# 2005-02-01  Cathedral City                                         0.0
# 2005-03-01  Cathedral City                                         0.0
# 2005-04-01  Cathedral City                                         0.0
# 2005-05-01  Cathedral City                                         0.0
#
#             Utilities  Construction  Manufacturing  Wholesale Trade  \
# DATE
# 2005-01-01        0.0         971.0           79.0            106.0
# 2005-02-01        0.0         981.0           68.0            108.0
# 2005-03-01        0.0        1032.0           78.0            111.0
# 2005-04-01        0.0         988.0           86.0            154.0
# 2005-05-01        0.0        1028.0           88.0            154.0
#
#             Retail Trade  Transportation and Warehousing  Information  \
# DATE
# 2005-01-01        1941.0                            39.0        137.0
# 2005-02-01        1956.0                            39.0        143.0
# 2005-03-01        1947.0                            41.0        142.0
# 2005-04-01        1936.0                            41.0        140.0
# 2005-05-01        1953.0                            39.0        135.0
#
#             Finance and Insurance  ...  Health Care and Social Assistance  \
# DATE                               ...
# 2005-01-01                  142.0  ...                              530.0
# 2005-02-01                  148.0  ...                              517.0
# 2005-03-01                  142.0  ...                              513.0
# 2005-04-01                  100.0  ...                              523.0
# 2005-05-01                   93.0  ...                              529.0
#
#             Arts, Entertainment, and Recreation  \
# DATE
# 2005-01-01                                217.0
# 2005-02-01                                224.0
# 2005-03-01                                236.0
# 2005-04-01                                234.0
# 2005-05-01                                245.0
#
#             Accommodation and Food Services  \
# DATE
# 2005-01-01                            967.0
# 2005-02-01                            990.0
# 2005-03-01                           1000.0
# 2005-04-01                           1023.0
# 2005-05-01                           1022.0
#
#             Other Services (except Public Administration)  Federal Government  \
# DATE
# 2005-01-01                                          543.0                 0.0
# 2005-02-01                                          547.0                 0.0
# 2005-03-01                                          561.0                 0.0
# 2005-04-01                                          546.0                 0.0
# 2005-05-01                                          552.0                 0.0
#
#             Local Government  State Government  Not Elsewhere Classified  \
# DATE
# 2005-01-01             940.0               0.0                       0.0
# 2005-02-01             941.0               0.0                       0.0
# 2005-03-01             953.0               0.0                       0.0
# 2005-04-01             906.0               0.0                       0.0
# 2005-05-01             910.0               0.0                       0.0
#
#             Mining, Quarrying, and Oil and Gas Extraction  Total Employment
# DATE
# 2005-01-01                                            0.0            7401.0
# 2005-02-01                                            0.0            7430.0
# 2005-03-01                                            0.0            7529.0
# 2005-04-01                                            0.0            7373.0
# 2005-05-01                                            0.0            7412.0
#
# [5 rows x 25 columns]

# %%
def get_city_df(city_name):
    city_df = empl_data.loc[empl_data.City == city_name]
    return city_df

# %%
cities = ['Cathedral City', 'Coachella', 'Desert Hot Springs', 'Indian Wells', 'Indio', 'La Quinta', 'Palm Desert', 'Palm Springs', 'Rancho Mirage']

# %%
# Out:
#                       City  Agriculture, Forestry, Fishing and Hunting  \
# DATE
# 2005-01-01  Cathedral City                                         0.0
# 2005-02-01  Cathedral City                                         0.0
# 2005-03-01  Cathedral City                                         0.0
# 2005-04-01  Cathedral City                                         0.0
# 2005-05-01  Cathedral City                                         0.0
# ...                    ...                                         ...
# 2021-08-01  Cathedral City                                         0.0
# 2021-09-01  Cathedral City                                         0.0
# 2021-10-01  Cathedral City                                         0.0
# 2021-11-01  Cathedral City                                         0.0
# 2021-12-01  Cathedral City                                         0.0
#
#             Utilities  Construction  Manufacturing  Wholesale Trade  \
# DATE
# 2005-01-01        0.0         971.0           79.0            106.0
# 2005-02-01        0.0         981.0           68.0            108.0
# 2005-03-01        0.0        1032.0           78.0            111.0
# 2005-04-01        0.0         988.0           86.0            154.0
# 2005-05-01        0.0        1028.0           88.0            154.0
# ...               ...           ...            ...              ...
# 2021-08-01        0.0           0.0            0.0              0.0
# 2021-09-01        0.0           0.0            0.0              0.0
# 2021-10-01        0.0           0.0            0.0              0.0
# 2021-11-01        0.0           0.0            0.0              0.0
# 2021-12-01        0.0           0.0            0.0              0.0
#
#             Retail Trade  Transportation and Warehousing  Information  \
# DATE
# 2005-01-01        1941.0                            39.0        137.0
# 2005-02-01        1956.0                            39.0        143.0
# 2005-03-01        1947.0                            41.0        142.0
# 2005-04-01        1936.0                            41.0        140.0
# 2005-05-01        1953.0                            39.0        135.0
# ...                  ...                             ...          ...
# 2021-08-01           0.0                             0.0          0.0
# 2021-09-01           0.0                             0.0          0.0
# 2021-10-01           0.0                             0.0          0.0
# 2021-11-01           0.0                             0.0          0.0
# 2021-12-01           0.0                             0.0          0.0
#
#             Finance and Insurance  ...  Health Care and Social Assistance  \
# DATE                               ...
# 2005-01-01                  142.0  ...                              530.0
# 2005-02-01                  148.0  ...                              517.0
# 2005-03-01                  142.0  ...                              513.0
# 2005-04-01                  100.0  ...                              523.0
# 2005-05-01                   93.0  ...                              529.0
# ...                           ...  ...                                ...
# 2021-08-01                    0.0  ...                                0.0
# 2021-09-01                    0.0  ...                                0.0
# 2021-10-01                    0.0  ...                                0.0
# 2021-11-01                    0.0  ...                                0.0
# 2021-12-01                    0.0  ...                                0.0
#
#             Arts, Entertainment, and Recreation  \
# DATE
# 2005-01-01                                217.0
# 2005-02-01                                224.0
# 2005-03-01                                236.0
# 2005-04-01                                234.0
# 2005-05-01                                245.0
# ...                                         ...
# 2021-08-01                                  0.0
# 2021-09-01                                  0.0
# 2021-10-01                                  0.0
# 2021-11-01                                  0.0
# 2021-12-01                                  0.0
#
#             Accommodation and Food Services  \
# DATE
# 2005-01-01                            967.0
# 2005-02-01                            990.0
# 2005-03-01                           1000.0
# 2005-04-01                           1023.0
# 2005-05-01                           1022.0
# ...                                     ...
# 2021-08-01                              0.0
# 2021-09-01                              0.0
# 2021-10-01                              0.0
# 2021-11-01                              0.0
# 2021-12-01                              0.0
#
#             Other Services (except Public Administration)  Federal Government  \
# DATE
# 2005-01-01                                          543.0                 0.0
# 2005-02-01                                          547.0                 0.0
# 2005-03-01                                          561.0                 0.0
# 2005-04-01                                          546.0                 0.0
# 2005-05-01                                          552.0                 0.0
# ...                                                   ...                 ...
# 2021-08-01                                            0.0                 0.0
# 2021-09-01                                            0.0                 0.0
# 2021-10-01                                            0.0                 0.0
# 2021-11-01                                            0.0                 0.0
# 2021-12-01                                            0.0                 0.0
#
#             Local Government  State Government  Not Elsewhere Classified  \
# DATE
# 2005-01-01             940.0               0.0                       0.0
# 2005-02-01             941.0               0.0                       0.0
# 2005-03-01             953.0               0.0                       0.0
# 2005-04-01             906.0               0.0                       0.0
# 2005-05-01             910.0               0.0                       0.0
# ...                      ...               ...                       ...
# 2021-08-01               0.0               0.0                       0.0
# 2021-09-01               0.0               0.0                       0.0
# 2021-10-01               0.0               0.0                       0.0
# 2021-11-01               0.0               0.0                       0.0
# 2021-12-01               0.0               0.0                       0.0
#
#             Mining, Quarrying, and Oil and Gas Extraction  Total Employment
# DATE
# 2005-01-01                                            0.0            7401.0
# 2005-02-01                                            0.0            7430.0
# 2005-03-01                                            0.0            7529.0
# 2005-04-01                                            0.0            7373.0
# 2005-05-01                                            0.0            7412.0
# ...                                                   ...               ...
# 2021-08-01                                            0.0               0.0
# 2021-09-01                                            0.0               0.0
# 2021-10-01                                            0.0               0.0
# 2021-11-01                                            0.0               0.0
# 2021-12-01                                            0.0               0.0
#
# [204 rows x 25 columns]

# %%
# Out:
#        DATE            City Agriculture, Forestry, Fishing and Hunting  \
# 0  Jan 2005  Cathedral City                                        NaN
# 1  Feb 2005  Cathedral City                                        NaN
# 2  Mar 2005  Cathedral City                                        NaN
# 3  Apr 2005  Cathedral City                                        NaN
# 4  May 2005  Cathedral City                                        NaN
#
#   Utilities Construction Manufacturing Wholesale Trade Retail Trade  \
# 0       NaN          971            79             106         1941
# 1       NaN          981            68             108         1956
# 2       NaN         1032            78             111         1947
# 3       NaN          988            86             154         1936
# 4       NaN         1028            88             154         1953
#
#   Transportation and Warehousing Information  ...  \
# 0                             39         137  ...
# 1                             39         143  ...
# 2                             41         142  ...
# 3                             41         140  ...
# 4                             39         135  ...
#
#   Health Care and Social Assistance  Arts, Entertainment, and Recreation  \
# 0                               530                                  217
# 1                               517                                  224
# 2                               513                                  236
# 3                               523                                  234
# 4                               529                                  245
#
#   Accommodation and Food Services  \
# 0                             967
# 1                             990
# 2                            1000
# 3                            1023
# 4                            1022
#
#   Other Services (except Public Administration) Federal Government  \
# 0                                           543                NaN
# 1                                           547                NaN
# 2                                           561                NaN
# 3                                           546                NaN
# 4                                           552                NaN
#
#   Local Government State Government Not Elsewhere Classified  \
# 0              940              NaN                      NaN
# 1              941              NaN                      NaN
# 2              953              NaN                      NaN
# 3              906              NaN                      NaN
# 4              910              NaN                      NaN
#
#   Mining, Quarrying, and Oil and Gas Extraction Total Employment
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
#
# [5 rows x 26 columns]

# %%
# Out:
#           DATE            City Agriculture, Forestry, Fishing and Hunting  \
# 0     Jan 2005  Cathedral City                                        NaN
# 1     Feb 2005  Cathedral City                                        NaN
# 2     Mar 2005  Cathedral City                                        NaN
# 3     Apr 2005  Cathedral City                                        NaN
# ...        ...             ...                                        ...
# 1832  Sep 2021   Rancho Mirage                                        NaN
# 1833  Oct 2021   Rancho Mirage                                        NaN
# 1834  Nov 2021   Rancho Mirage                                        NaN
# 1835  Dec 2021   Rancho Mirage                                        NaN
#
#      Utilities Construction Manufacturing Wholesale Trade Retail Trade  \
# 0          NaN          971            79             106         1941
# 1          NaN          981            68             108         1956
# 2          NaN         1032            78             111         1947
# 3          NaN          988            86             154         1936
# ...        ...          ...           ...             ...          ...
# 1832       NaN          NaN           NaN             NaN          NaN
# 1833       NaN          NaN           NaN             NaN          NaN
# 1834       NaN          NaN           NaN             NaN          NaN
# 1835       NaN          NaN           NaN             NaN          NaN
#
#      Transportation and Warehousing Information  ... Educational Services  \
# 0                                39         137  ...                   21
# 1                                39         143  ...                   14
# 2                                41         142  ...                   21
# 3                                41         140  ...                   20
# ...                             ...         ...  ...                  ...
# 1832                            NaN         NaN  ...                  NaN
# 1833                            NaN         NaN  ...                  NaN
# 1834                            NaN         NaN  ...                  NaN
# 1835                            NaN         NaN  ...                  NaN
#
#       Health Care and Social Assistance Arts, Entertainment, and Recreation  \
# 0                                   530                                 217
# 1                                   517                                 224
# 2                                   513                                 236
# 3                                   523                                 234
# ...                                 ...                                 ...
# 1832                                NaN                                 NaN
# 1833                                NaN                                 NaN
# 1834                                NaN                                 NaN
# 1835                                NaN                                 NaN
#
#      Accommodation and Food Services  \
# 0                                967
# 1                                990
# 2                               1000
# 3                               1023
# ...                              ...
# 1832                             NaN
# 1833                             NaN
# 1834                             NaN
# 1835                             NaN
#
#      Other Services (except Public Administration) Federal Government  \
# 0                                              543                NaN
# 1                                              547                NaN
# 2                                              561                NaN
# 3                                              546                NaN
# ...                                            ...                ...
# 1832                                           NaN                NaN
# 1833                                           NaN                NaN
# 1834                                           NaN                NaN
# 1835                                           NaN                NaN
#
#      Local Government State Government Not Elsewhere Classified  \
# 0                 940              NaN                      NaN
# 1                 941              NaN                      NaN
# 2                 953              NaN                      NaN
# 3                 906              NaN                      NaN
# ...               ...              ...                      ...
# 1832              NaN              NaN                      NaN
# 1833              NaN              NaN                      NaN
# 1834              NaN              NaN                      NaN
# 1835              NaN              NaN                      NaN
#
#      Mining, Quarrying, and Oil and Gas Extraction
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# ...                                            ...
# 1832                                           NaN
# 1833                                           NaN
# 1834                                           NaN
# 1835                                           NaN
#
# [1836 rows x 25 columns]

# %%
# Out:
#        DATE            City Agriculture, Forestry, Fishing and Hunting  \
# 0  Jan 2005  Cathedral City                                        NaN
# 1  Feb 2005  Cathedral City                                        NaN
# 2  Mar 2005  Cathedral City                                        NaN
# 3  Apr 2005  Cathedral City                                        NaN
# 4  May 2005  Cathedral City                                        NaN
#
#   Utilities Construction Manufacturing Wholesale Trade Retail Trade  \
# 0       NaN          971            79             106         1941
# 1       NaN          981            68             108         1956
# 2       NaN         1032            78             111         1947
# 3       NaN          988            86             154         1936
# 4       NaN         1028            88             154         1953
#
#   Transportation and Warehousing Information  ...  \
# 0                             39         137  ...
# 1                             39         143  ...
# 2                             41         142  ...
# 3                             41         140  ...
# 4                             39         135  ...
#
#   Health Care and Social Assistance  Arts, Entertainment, and Recreation  \
# 0                               530                                  217
# 1                               517                                  224
# 2                               513                                  236
# 3                               523                                  234
# 4                               529                                  245
#
#   Accommodation and Food Services  \
# 0                             967
# 1                             990
# 2                            1000
# 3                            1023
# 4                            1022
#
#   Other Services (except Public Administration) Federal Government  \
# 0                                           543                NaN
# 1                                           547                NaN
# 2                                           561                NaN
# 3                                           546                NaN
# 4                                           552                NaN
#
#   Local Government State Government Not Elsewhere Classified  \
# 0              940              NaN                      NaN
# 1              941              NaN                      NaN
# 2              953              NaN                      NaN
# 3              906              NaN                      NaN
# 4              910              NaN                      NaN
#
#   Mining, Quarrying, and Oil and Gas Extraction Total Employment
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
#
# [5 rows x 26 columns]

# %%
# Out:
#        DATE            City Agriculture, Forestry, Fishing and Hunting  \
# 0  Jan 2005  Cathedral City                                        NaN
# 1  Feb 2005  Cathedral City                                        NaN
# 2  Mar 2005  Cathedral City                                        NaN
# 3  Apr 2005  Cathedral City                                        NaN
# 4  May 2005  Cathedral City                                        NaN
#
#   Utilities Construction Manufacturing Wholesale Trade Retail Trade  \
# 0       NaN          971            79             106         1941
# 1       NaN          981            68             108         1956
# 2       NaN         1032            78             111         1947
# 3       NaN          988            86             154         1936
# 4       NaN         1028            88             154         1953
#
#   Transportation and Warehousing Information  ...  \
# 0                             39         137  ...
# 1                             39         143  ...
# 2                             41         142  ...
# 3                             41         140  ...
# 4                             39         135  ...
#
#   Health Care and Social Assistance  Arts, Entertainment, and Recreation  \
# 0                               530                                  217
# 1                               517                                  224
# 2                               513                                  236
# 3                               523                                  234
# 4                               529                                  245
#
#   Accommodation and Food Services  \
# 0                             967
# 1                             990
# 2                            1000
# 3                            1023
# 4                            1022
#
#   Other Services (except Public Administration) Federal Government  \
# 0                                           543                NaN
# 1                                           547                NaN
# 2                                           561                NaN
# 3                                           546                NaN
# 4                                           552                NaN
#
#   Local Government State Government Not Elsewhere Classified  \
# 0              940              NaN                      NaN
# 1              941              NaN                      NaN
# 2              953              NaN                      NaN
# 3              906              NaN                      NaN
# 4              910              NaN                      NaN
#
#   Mining, Quarrying, and Oil and Gas Extraction Total Employment
# 0                                           NaN            215.0
# 1                                           NaN            217.0
# 2                                           NaN            219.0
# 3                                           NaN            217.0
# 4                                           NaN            218.0
#
# [5 rows x 26 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/kc/96gd8w257616fkgyr9gcth3h0000gn/T/ipykernel_41061/3716643189.py in <module>
# ----> 1 empl_data['Total Employment'] = empl_data.loc[:, ["Agriculture, Forestry, Fishing and Hunting"]:].sum(axis=1, skipna=True, numeric_only=True)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1107             return self._multi_take(tup)
#    1108
# -> 1109         return self._getitem_tuple_same_dim(tup)
#    1110
#    1111     def _get_label(self, label, axis: int):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
#     804                 continue
#     805
# --> 806             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     807             # We should never have retval.ndim < self.ndim, as that should
#     808             #  be handled by the _getitem_lowerdim call above.
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1174
#    1175         labels = obj._get_axis(axis)
# -> 1176         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1177
#    1178         if isinstance(indexer, slice):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    5683         slice(1, 3, None)
#    5684         """
# -> 5685         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5686
#    5687         # return a slice
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    5885         start_slice = None
#    5886         if start is not None:
# -> 5887             start_slice = self.get_slice_bound(start, "left")
#    5888         if start_slice is None:
#    5889             start_slice = 0
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    5799         # we need to look up the label
#    5800         try:
# -> 5801             slc = self.get_loc(label)
#    5802         except KeyError as err:
#    5803             try:
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '['Agriculture, Forestry, Fishing and Hunting']' is an invalid key

# %%
# Out:
#        DATE            City Agriculture, Forestry, Fishing and Hunting  \
# 0  Jan 2005  Cathedral City                                        NaN
# 1  Feb 2005  Cathedral City                                        NaN
# 2  Mar 2005  Cathedral City                                        NaN
# 3  Apr 2005  Cathedral City                                        NaN
# 4  May 2005  Cathedral City                                        NaN
#
#   Utilities Construction Manufacturing Wholesale Trade Retail Trade  \
# 0       NaN          971            79             106         1941
# 1       NaN          981            68             108         1956
# 2       NaN         1032            78             111         1947
# 3       NaN          988            86             154         1936
# 4       NaN         1028            88             154         1953
#
#   Transportation and Warehousing Information  ...  \
# 0                             39         137  ...
# 1                             39         143  ...
# 2                             41         142  ...
# 3                             41         140  ...
# 4                             39         135  ...
#
#   Health Care and Social Assistance  Arts, Entertainment, and Recreation  \
# 0                               530                                  217
# 1                               517                                  224
# 2                               513                                  236
# 3                               523                                  234
# 4                               529                                  245
#
#   Accommodation and Food Services  \
# 0                             967
# 1                             990
# 2                            1000
# 3                            1023
# 4                            1022
#
#   Other Services (except Public Administration) Federal Government  \
# 0                                           543                NaN
# 1                                           547                NaN
# 2                                           561                NaN
# 3                                           546                NaN
# 4                                           552                NaN
#
#   Local Government State Government Not Elsewhere Classified  \
# 0              940              NaN                      NaN
# 1              941              NaN                      NaN
# 2              953              NaN                      NaN
# 3              906              NaN                      NaN
# 4              910              NaN                      NaN
#
#   Mining, Quarrying, and Oil and Gas Extraction Total Employment
# 0                                           NaN            430.0
# 1                                           NaN            434.0
# 2                                           NaN            438.0
# 3                                           NaN            434.0
# 4                                           NaN            436.0
#
# [5 rows x 26 columns]

# %%
# Out:
# /var/folders/kc/96gd8w257616fkgyr9gcth3h0000gn/T/ipykernel_41061/431044449.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   empl_data['Total Employment'] = empl_data.loc[:, "Agriculture, Forestry, Fishing and Hunting":].sum(axis=1)

# %%
# Out:
#        DATE            City Agriculture, Forestry, Fishing and Hunting  \
# 0  Jan 2005  Cathedral City                                        NaN
# 1  Feb 2005  Cathedral City                                        NaN
# 2  Mar 2005  Cathedral City                                        NaN
# 3  Apr 2005  Cathedral City                                        NaN
# 4  May 2005  Cathedral City                                        NaN
#
#   Utilities Construction Manufacturing Wholesale Trade Retail Trade  \
# 0       NaN          971            79             106         1941
# 1       NaN          981            68             108         1956
# 2       NaN         1032            78             111         1947
# 3       NaN          988            86             154         1936
# 4       NaN         1028            88             154         1953
#
#   Transportation and Warehousing Information  ...  \
# 0                             39         137  ...
# 1                             39         143  ...
# 2                             41         142  ...
# 3                             41         140  ...
# 4                             39         135  ...
#
#   Health Care and Social Assistance  Arts, Entertainment, and Recreation  \
# 0                               530                                  217
# 1                               517                                  224
# 2                               513                                  236
# 3                               523                                  234
# 4                               529                                  245
#
#   Accommodation and Food Services  \
# 0                             967
# 1                             990
# 2                            1000
# 3                            1023
# 4                            1022
#
#   Other Services (except Public Administration) Federal Government  \
# 0                                           543                NaN
# 1                                           547                NaN
# 2                                           561                NaN
# 3                                           546                NaN
# 4                                           552                NaN
#
#   Local Government State Government Not Elsewhere Classified  \
# 0              940              NaN                      NaN
# 1              941              NaN                      NaN
# 2              953              NaN                      NaN
# 3              906              NaN                      NaN
# 4              910              NaN                      NaN
#
#   Mining, Quarrying, and Oil and Gas Extraction Total Employment
# 0                                           NaN              0.0
# 1                                           NaN              0.0
# 2                                           NaN              0.0
# 3                                           NaN              0.0
# 4                                           NaN              0.0
#
# [5 rows x 26 columns]

# %%
# Out:
#   File "/var/folders/kc/96gd8w257616fkgyr9gcth3h0000gn/T/ipykernel_41061/3181421605.py", line 1
#     empl_data['Total Employment'] = empl_data.loc[:, ["Agriculture, Forestry, Fishing and Hunting":]].sum(axis=1, numeric_only=True)
#                                                                                                   ^
# SyntaxError: invalid syntax

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/kc/96gd8w257616fkgyr9gcth3h0000gn/T/ipykernel_54443/3513799721.py in <module>
# ----> 1 empl_data.set_index('DATE', inplace=True)
#
# NameError: name 'empl_data' is not defined
